# %%
import json
import pandas as pd

# %%
with open('user.json') as file:
    data = json.load(file)
data
# Out:
# {'users': [{'id': 1,
#    'firstName': 'Terry',
#    'lastName': 'Medhurst',
#    'maidenName': 'Smitham',
#    'age': 50,
#    'gender': 'male',
#    'email': 'atuny0@sohu.com',
#    'phone': '+63 791 675 8914',
#    'username': 'atuny0',
#    'password': '9uQFF1Lh',
#    'birthDate': '2000-12-25',
#    'image': 'https://robohash.org/hicveldicta.png',
#    'bloodGroup': 'A−',
#    'height': 189,
#    'weight': 75.4,
#    'eyeColor': 'Green',
#    'hair': {'color': 'Black', 'type': 'Strands'},
#    'domain': 'slashdot.org',
#    'ip': '117.29.86.254',
#    'address': {'address': '1745 T Street Southeast',
#     'city': 'Washington',
#     'coordinates': {'lat': 38.867033, 'lng': -76.979235},
#     'postalCode': '20020',
#     'state': 'DC'},
#    'macAddress': '13:69:BA:56:A3:74',
#    'university': 'Capitol University',
#    'bank': {'cardExpire': '06/22',
#     'cardNumber': '50380955204220685',
#     'cardType': 'maestro',
#     'currency': 'Peso',
# ...

# %%
df = pd.json_normalize(data, record_path=['users'])

# %%
df2 = pd.DataFrame(df)
df2.head(2)
# Out:
#    id firstName  lastName maidenName  age gender                  email  \
# 0   1     Terry  Medhurst    Smitham   50   male        atuny0@sohu.com
# 1   2   Sheldon   Quigley       Cole   28   male  hbingley1@plala.or.jp
#
#               phone   username    password  ...  \
# 0  +63 791 675 8914     atuny0    9uQFF1Lh  ...
# 1   +7 813 117 7139  hbingley1  CQutx25i8r  ...
#
#                        bank.iban  company.address.address  \
# 0             NO17 0695 2754 967         629 Debbie Drive
# 1  MD63 L6YC 8YH4 QVQB XHIK MTML  8821 West Myrtle Avenue
#
#   company.address.city  company.address.coordinates.lat  \
# 0            Nashville                        36.208114
# 1             Glendale                        33.540430
#
#    company.address.coordinates.lng company.address.postalCode  \
# 0                       -86.586212                      37076
# 1                      -112.248839                      85305
#
# ...

# %%
with open('hashed_passwords.txt') as fh:
    hashed = fh.readlines()

hash_lst = []

for hash in hashed:
    hash = hash.rstrip()
    hash_lst.append(hash)

hash_lst
# Out:
# ['$2b$12$7TKu2ekLtNIrv6v2YMmUC.LvoWXXXeU2sqbE2/YUmCAh5qnd8Ng/O',
#  '$2b$12$0s8WYWiESNjT4g6mPFw9Nucs3vJCYyYGIDxvznI1YH7Y8ZT975h1y',
#  '$2b$12$lm6dyfVTQU1Ssbfl8sLpr.wvDD5WBajcOIhgkBkLJsz8NHfcU.VPS',
#  '$2b$12$WdESak7aHu9NpOlNLS6sLu4JF/YYCXcfDb9MATsFeYmjMvXS9bnpK',
#  '$2b$12$wIFRhKY7uaANk4CjrSBq7ex3S3zrV2.T3s4UTTwwYdgIaEsNqcifa',
#  '$2b$12$k3FBeiToTewN.kivc7MQoujuekwqfumT.Ga9E4cffdOM8CG9RXa8W',
#  '$2b$12$rbP0vgqfcqs8vSNLzjxZEu8QjpeN7gAt5dTDYEidHG1Z8Uq03Y2z.',
#  '$2b$12$dOPXlySWJxeqC6746yu1cOTskb0O3.AmFVnM3yc5/67BpmxNnn9yG',
#  '$2b$12$CgvMZo5ryT5pINUJD9x.3OSeZ5vQBlLC3vG9xKCdimDgtIRIFW5/e',
#  '$2b$12$j56KqK7Ta3xxjRWBhFhD.OWJGniRWB5Xog4efiik0SYFbZBr9bJ26',
#  '$2b$12$KpDo/RPNNM9Ms36pstpgN.ZvqRXIN1w.Lzza9x0r/ztWAnEKOMzlS',
#  '$2b$12$y8JeJf9QdaKcsPVBzjhcx.mf32rGgmxhmZTea.Vr635KHtQMP7mcO',
#  '$2b$12$i2fpyzTYitMsApcU.BaBj.5OjEshLsmvTIFfBqtktxGBYYBW8jhCi',
#  '$2b$12$vA4hUfeVBLxF71SqoTXn5.BQs19540aeUEb87iLWeDR/yk7qEJ7Ta',
# ...

# %%
pass_lst = df2['password'].to_list()
pass_lst
# Out:
# ['9uQFF1Lh',
#  'CQutx25i8r',
#  'OWsTbMUgFc',
#  'sRQxjPfdS',
#  'aUTdmmmbH',
#  'zY1nE46Zm',
#  'YVmhktgYVS',
#  'MWwlaeWcOoF6',
#  'HTQxxXV9Bq4',
#  'i0xzpX',
#  'M9lbMdydMN',
#  'esTkitT1r',
#  'ftGj8LZTtv9g',
#  'GyLnCB8gNIp',
#  '0lelplR',
#  'Vru55Y4tufI4',
#  'mSPzYZfR',
#  'cAjfb8vg',
#  'UZGAiqPqWQHQ',
#  'szWAG6hc',
#  'tq7kPXyf',
#  'rfVSKImC',
#  'zQwaHTHbuZyr',
#  'bMQnPttV',
#  'k9zgV68UKw8m',
#  '4a1dAKDv9KB9',
#  'xZnWSWnqH',
#  'HLDqN5vCF',
#  'ePawWgrnZR8L',
#  '5t6q4KC7O']

# %%
df['password'] = df['password'].replace(pass_lst,hash_lst)

# %%
phone_lst = df2['phone'].to_list()

new_phone_lst = []

for phone in phone_lst:

    for num in phone:
        if num.isdigit():
            phone = phone.replace(num,'X',5)

    num_str = phone.rstrip()
    num_spl = num_str.split(' ')

    new_phone = '-'.join(num_spl)

    new_phone_lst.append(new_phone)

new_phone_lst

# Doesn't work as expected
# Out:
# ['+XX-XXX-XXX-XXXX',
#  '+X-XXX-XXX-XXXX',
#  '+XX-XXX-XXX-XXXX',
#  '+XX-XXX-XXX-XXXX',
#  '+XXX-XXX-XXX-XXXX',
#  '+XXX-XXX-XXX-XXXX',
#  '+XX-XXX-XXX-XXXX',
#  '+XX-XXX-XXX-XXXX',
#  '+XX-XXX-XXX-XXXX',
#  '+XX-XXX-XXX-XXXX',
#  '+XXX-XXX-XXX-XXXX',
#  '+XXX-XXX-XXX-XXXX',
#  '+X-XXX-XXX-XXXX',
#  '+XX-XXX-XXX-XXXX',
#  '+XX-XXX-XXX-XXXX',
#  '+XXX-XXX-XXX-XXXX',
#  '+XXX-XXX-XXX-XXXX',
#  '+XX-XXX-XXX-XXXX',
#  '+XX-XXX-XXX-XXXX',
#  '+X-XXX-XXX-XXXX',
#  '+XX-XXX-XXX-XXXX',
#  '+XX-XXX-XXX-XXXX',
#  '+XX-XXX-XXX-XXXX',
#  '+X-XXX-XXX-XXXX',
#  '+XX-XXX-XXX-XXXX',
#  '+XX-XXX-XXX-XXXX',
#  '+XX-XXX-XXX-XXXX',
#  '+XX-XXX-XXX-XXXX',
#  '+XX-XXX-XXX-XXXX',
#  '+XX-XXX-XXX-XXXX']

# %%
df2.to_csv('user.csv',sep=',')
